# %%
import pandas as pd
import numpy as np
used_cars= pd.read_csv(r'C:\Users\s_kel\OneDrive\Documents\Programming for Analytics\project\used_cars_data.csv',index_col=0)
used_cars.head()
# Out:
#                                    Name    Location  Year  Kilometers_Driven  \
# S.No.
# 0                Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1      Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                          Honda Jazz V     Chennai  2011              46000
# 3                     Maruti Ertiga VDI     Chennai  2012              87000
# 4       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#       Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  \
# S.No.
# 0           CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp
# 1        Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp
# 2        Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp
# 3        Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp
# 4        Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp
#
#        Seats  New_Price  Price
# S.No.
# ...

# %%
# Understanding the DataSet

# %%
used_cars.tail()
# Out:
#                                                     Name   Location  Year  \
# S.No.
# 7248                   Volkswagen Vento Diesel Trendline  Hyderabad  2011
# 7249                              Volkswagen Polo GT TSI     Mumbai  2015
# 7250                              Nissan Micra Diesel XV    Kolkata  2012
# 7251                              Volkswagen Polo GT TSI       Pune  2013
# 7252   Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi  2014
#
#        Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# S.No.
# 7248               89411    Diesel       Manual      First  20.54 kmpl
# 7249               59000    Petrol    Automatic      First  17.21 kmpl
# 7250               28000    Diesel       Manual      First  23.08 kmpl
# 7251               52262    Petrol    Automatic      Third   17.2 kmpl
# 7252               72443    Diesel    Automatic      First   10.0 kmpl
#
#         Engine      Power  Seats New_Price  Price
# S.No.
# ...

# %%
used_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  New_Price          1006 non-null   object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 793.3+ KB

# %%
used_cars.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price
# count  7253.000000       7.253000e+03  7200.000000  6019.000000
# mean   2013.365366       5.869906e+04     5.279722     9.479468
# std       3.254421       8.442772e+04     0.811660    11.187917
# min    1996.000000       1.710000e+02     0.000000     0.440000
# 25%    2011.000000       3.400000e+04     5.000000     3.500000
# 50%    2014.000000       5.341600e+04     5.000000     5.640000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000
# max    2019.000000       6.500000e+06    10.000000   160.000000

# %%
used_cars.shape
# Out:
# (7253, 13)

# %%
used_cars.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')>

# %%
used_cars.isnull().sum().sort_values(ascending=False)
# Out:
# New_Price            6247
# Price                1234
# Seats                  53
# Engine                 46
# Power                  46
# Mileage                 2
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# dtype: int64

# %%
used_cars.nunique()
# Out:
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               450
# Engine                150
# Power                 386
# Seats                   9
# New_Price             625
# Price                1373
# dtype: int64

# %%
used_cars['Name'].value_counts()
# Out:
# Mahindra XUV500 W8 2WD                              55
# Maruti Swift VDI                                    49
# Maruti Swift Dzire VDI                              42
# Honda City 1.5 S MT                                 39
# Maruti Swift VDI BSIV                               37
#                                                     ..
# Maruti Celerio ZXI Optional                          1
# Mercedes-Benz E-Class 2009-2013 E250 CDI Classic     1
# Maruti Swift ZXI Plus                                1
# Ford Endeavour 4x2 XLT                               1
# Ford Endeavour XLT TDCi 4X4                          1
# Name: Name, Length: 2041, dtype: int64

# %%
used_cars['Location'].value_counts()
# Out:
# Mumbai        949
# Hyderabad     876
# Coimbatore    772
# Kochi         772
# Pune          765
# Delhi         660
# Kolkata       654
# Chennai       591
# Jaipur        499
# Bangalore     440
# Ahmedabad     275
# Name: Location, dtype: int64

# %%
used_cars['Fuel_Type'].value_counts()
# Out:
# Diesel      3852
# Petrol      3325
# CNG           62
# LPG           12
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
used_cars['Transmission'].value_counts()
# Out:
# Manual       5204
# Automatic    2049
# Name: Transmission, dtype: int64

# %%
used_cars['Owner_Type'].value_counts()
# Out:
# First             5952
# Second            1152
# Third              137
# Fourth & Above      12
# Name: Owner_Type, dtype: int64

# %%
used_cars[['Mileage','Engine','Power','New_Price']].sample(10)
# Out:
#           Mileage   Engine      Power New_Price
# S.No.
# 3354   15.04 kmpl  1598 CC  103.6 bhp       NaN
# 2933   12.99 kmpl  2494 CC  100.6 bhp       NaN
# 4913    24.4 kmpl  1120 CC     71 bhp       NaN
# 4405    14.4 kmpl  1598 CC  103.6 bhp       NaN
# 3683    25.2 kmpl  1248 CC     74 bhp       NaN
# 6796    11.5 kmpl  2982 CC    171 bhp       NaN
# 443      0.0 kmpl  1086 CC   null bhp       NaN
# 6149   23.59 kmpl  1364 CC  67.04 bhp       NaN
# 1460     0.0 kmpl      NaN        NaN       NaN
# 5068    15.1 kmpl  2179 CC    140 bhp       NaN

# %%
#confirming the 0s in mileage is Nan
used_cars[used_cars.Mileage.isnull()==True]
# Out:
#                             Name Location  Year  Kilometers_Driven Fuel_Type  \
# S.No.
# 4446        Mahindra E Verito D4  Chennai  2016              50000  Electric
# 4904   Toyota Prius 2009-2016 Z4   Mumbai  2011              44000  Electric
#
#       Transmission Owner_Type Mileage   Engine   Power  Seats   New_Price  \
# S.No.
# 4446     Automatic      First     NaN    72 CC  41 bhp    5.0  13.58 Lakh
# 4904     Automatic      First     NaN  1798 CC  73 bhp    5.0         NaN
#
#        Price
# S.No.
# 4446   13.00
# 4904   12.75

# %%
# Mileage
used_cars['Mileage'] = used_cars['Mileage'].str.replace('kmpl','')
used_cars['Mileage']= used_cars['Mileage'].str.replace('km/kg','')
used_cars['Mileage'].head(3)
# Out:
# S.No.
# 0     26.6
# 1    19.67
# 2     18.2
# Name: Mileage, dtype: object

# %%
# Engine
used_cars['Engine']=used_cars['Engine'].str.replace('CC','')
used_cars['Engine'].head(3)
# Out:
# S.No.
# 0     998
# 1    1582
# 2    1199
# Name: Engine, dtype: object

# %%
used_cars['Power']=used_cars["Power"].str.rstrip(" bhp")
used_cars['Power']= used_cars['Power'].replace(regex='null', value = np.nan)
used_cars['Power'].head(3)
# Out:
# S.No.
# 0    58.16
# 1    126.2
# 2     88.7
# Name: Power, dtype: object

# %%
used_cars['New_Price']=used_cars['New_Price'].str.replace('Lakh','')
used_cars['New_Price']=used_cars['New_Price'].str.replace('Cr','')
used_cars['New_Price'].head(3)
# Out:
# S.No.
# 0      NaN
# 1      NaN
# 2    8.61
# Name: New_Price, dtype: object

# %%
replaced_values=used_cars[['Power','Engine','Mileage','New_Price']]
replaced_values.sample(10)
# Out:
#         Power Engine Mileage New_Price
# S.No.
# 4193   138.03  1968   16.96        NaN
# 2351       82  1197    18.9        NaN
# 5167     93.7  1373   16.02        NaN
# 1602       37   796    16.1        NaN
# 6689       35   796    14.0        NaN
# 1263      118  1497    17.0        NaN
# 3807       66  1896    18.7        NaN
# 3596     88.8  1248   20.77        NaN
# 4169    53.64   799    22.7      4.05
# 300     100.6  2494   12.99        NaN

# %%
replaced_values.query("Power == '0.0'")['Power'].count()
# Out:
# 0

# %%
replaced_values.query("Mileage == '0.0'")['Mileage'].count()
# Out:
# 0

# %%
replaced_values.nunique()
# Out:
# Power        385
# Engine       150
# Mileage      438
# New_Price    625
# dtype: int64

# %%
replaced_values.isnull().sum()
# Out:
# Power         175
# Engine         46
# Mileage         2
# New_Price    6247
# dtype: int64

# %%
#converting object data (replaced_values) type to float
replaced_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7253 entries, 0 to 7252
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Power      7078 non-null   object
#  1   Engine     7207 non-null   object
#  2   Mileage    7251 non-null   object
#  3   New_Price  1006 non-null   object
# dtypes: object(4)
# memory usage: 541.4+ KB

# %%
#import numpy as np

# %%
#replacing 0 in seats with nan
used_cars.loc[3999,'Seats'] =np.nan
used_cars['Seats'].head()
# Out:
# S.No.
# 0    5.0
# 1    5.0
# 2    5.0
# 3    7.0
# 4    5.0
# Name: Seats, dtype: float64

# %%
#converting object data (replaced_values) type to float
used_cars['Power']= used_cars['Power'].astype(float)
used_cars['Engine']= used_cars['Engine'].astype(float)
used_cars['Mileage']= used_cars['Mileage'].astype(float)
#used_cars['New_Price']= used_cars['New_Price'].astype(float)

# %%
used_cars['Engine']. head()
# Out:
# S.No.
# 0     998.0
# 1    1582.0
# 2    1199.0
# 3    1248.0
# 4    1968.0
# Name: Engine, dtype: float64

# %%
used_cars['Engine']. isnull().sum()
# Out:
# 46

# %%
used_cars['Mileage']. isnull().sum()
# Out:
# 2

# %%
used_cars['Power']. isnull().sum()
# Out:
# 175

# %%
used_cars['New_Price']= used_cars['New_Price'].astype(float)

# %%
used_cars['New_Price']. isnull().sum()
# Out:
# 6247

# %%
used_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   float64
#  8   Engine             7207 non-null   float64
#  9   Power              7078 non-null   float64
#  10  Seats              7199 non-null   float64
#  11  New_Price          1006 non-null   float64
#  12  Price              6019 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 1.0+ MB

# %%
used_cars.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  7253.000000       7.253000e+03  7251.000000  7207.000000  7078.000000
# mean   2013.365366       5.869906e+04    18.141580  1616.573470   112.765214
# std       3.254421       8.442772e+04     4.562197   595.285137    53.493553
# min    1996.000000       1.710000e+02     0.000000    72.000000    34.200000
# 25%    2011.000000       3.400000e+04    15.170000  1198.000000    75.000000
# 50%    2014.000000       5.341600e+04    18.160000  1493.000000    94.000000
# 75%    2016.000000       7.300000e+04    21.100000  1968.000000   138.100000
# max    2019.000000       6.500000e+06    33.540000  5998.000000   616.000000
#
#              Seats    New_Price        Price
# count  7199.000000  1006.000000  6019.000000
# mean      5.280456    19.894324     9.479468
# std       0.809327    19.813947    11.187917
# min       2.000000     1.000000     0.440000
# 25%       5.000000     7.635000     3.500000
# ...

# %%
#to determine how old a car is
used_cars['current_year']=2021
used_cars['age'] = used_cars['current_year']-used_cars['Year']
used_cars.head()
# Out:
#                                    Name    Location  Year  Kilometers_Driven  \
# S.No.
# 0                Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1      Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                          Honda Jazz V     Chennai  2011              46000
# 3                     Maruti Ertiga VDI     Chennai  2012              87000
# 4       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#       Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# S.No.
# 0           CNG       Manual      First    26.60   998.0   58.16    5.0
# 1        Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2        Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3        Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4        Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#        New_Price  Price  current_year  age
# S.No.
# ...

# %%
#dropping the current year column
used_cars.drop(columns='current_year',inplace=True)
used_cars.head()
# Out:
#                                    Name    Location  Year  Kilometers_Driven  \
# S.No.
# 0                Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1      Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                          Honda Jazz V     Chennai  2011              46000
# 3                     Maruti Ertiga VDI     Chennai  2012              87000
# 4       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#       Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# S.No.
# 0           CNG       Manual      First    26.60   998.0   58.16    5.0
# 1        Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2        Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3        Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4        Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#        New_Price  Price  age
# S.No.
# ...

# %%
#Seperating Make and Model from Name
used_cars['Make']= used_cars['Name'].str.split(' ').str[0]
used_cars['Model']= used_cars['Name'].str.split(' ').str[1]+used_cars['Name'].str.split(' ').str[2]
used_cars.head(5)
# Out:
#                                    Name    Location  Year  Kilometers_Driven  \
# S.No.
# 0                Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1      Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                          Honda Jazz V     Chennai  2011              46000
# 3                     Maruti Ertiga VDI     Chennai  2012              87000
# 4       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#       Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# S.No.
# 0           CNG       Manual      First    26.60   998.0   58.16    5.0
# 1        Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2        Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3        Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4        Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#        New_Price  Price  age     Make      Model
# ...

# %%
used_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7253 entries, 0 to 7252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   float64
#  8   Engine             7207 non-null   float64
#  9   Power              7078 non-null   float64
#  10  Seats              7199 non-null   float64
#  11  New_Price          1006 non-null   float64
#  12  Price              6019 non-null   float64
#  13  age                7253 non-null   int64
#  14  Make               7253 non-null   object
#  15  Model              7252 non-null   object
# ...

# %%
used_cars['Make'].value_counts()
# Out:
# Maruti           1444
# Hyundai          1340
# Honda             743
# Toyota            507
# Mercedes-Benz     380
# Volkswagen        374
# Ford              351
# Mahindra          331
# BMW               312
# Audi              285
# Tata              228
# Skoda             202
# Renault           170
# Chevrolet         151
# Nissan            117
# Land               67
# Jaguar             48
# Fiat               38
# Mitsubishi         36
# Mini               31
# Volvo              28
# Jeep               19
# Porsche            19
# Datsun             17
# Force               3
# ISUZU               3
# Bentley             2
# Isuzu               2
# Ambassador          1
# OpelCorsa           1
# Hindustan           1
# Smart               1
# Lamborghini         1
# Name: Make, dtype: int64

# %%
#Makes like Isuzu and ISUZU  are the same. Mini sounds like Mini cooper and land more like land Rover. we need to make adjustments to these
col=['ISUZU','Isuzu','Mini','Land']
used_cars[used_cars.Make.isin(col)].sample(5)
# Out:
#                               Name   Location  Year  Kilometers_Driven  \
# S.No.
# 3277          Mini Cooper 3 DOOR D      Kochi  2016              32298
# 1117          Mini Cooper 5 DOOR D  Ahmedabad  2014              34000
# 391    Mini Cooper Convertible 1.6  Bangalore  2015              20000
# 2364     Mini Cooper Convertible S    Chennai  2012              17000
# 1476      Mini Cooper Countryman D  Hyderabad  2013              51000
#
#       Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# S.No.
# 3277     Diesel    Automatic      First    20.70  1496.0  113.98    4.0
# 1117     Diesel    Automatic      First    20.70  1496.0  113.98    5.0
# 391      Petrol    Automatic      First    18.86  1598.0  122.00    4.0
# 2364     Petrol    Automatic     Second    16.82  1998.0  189.08    4.0
# 1476     Diesel    Automatic      First    23.80  1998.0  112.00    5.0
#
#        New_Price  Price  age  Make              Model
# S.No.
# ...

# %%
#where the data changed occures

#used_cars.loc[used_cars.Make == 'ISUZU']='Isuzu'
#used_cars.loc[used_cars.Make=='Mini']='Mini Cooper'
#used_cars.loc[used_cars.Make=='Land']='Land Rover'

# %%
#I Think this works
used_cars['Make'].replace(['ISUZU','Mini','Land'],['Isuzu','Mini Cooper','Land Rover'],inplace=True)

# %%
used_cars['Make'].value_counts()
# Out:
# Maruti           1444
# Hyundai          1340
# Honda             743
# Toyota            507
# Mercedes-Benz     380
# Volkswagen        374
# Ford              351
# Mahindra          331
# BMW               312
# Audi              285
# Tata              228
# Skoda             202
# Renault           170
# Chevrolet         151
# Nissan            117
# Land Rover         67
# Jaguar             48
# Fiat               38
# Mitsubishi         36
# Mini Cooper        31
# Volvo              28
# Porsche            19
# Jeep               19
# Datsun             17
# Isuzu               5
# Force               3
# Bentley             2
# Hindustan           1
# OpelCorsa           1
# Ambassador          1
# Smart               1
# Lamborghini         1
# Name: Make, dtype: int64

# %%
used_cars.Model.isnull().sum()
# Out:
# 1

# %%
#drop row with no model
used_cars.dropna(subset=['Model'],axis=0,inplace=True)

# %%
used_cars.Model.isnull().sum()
# Out:
# 0

# %%
used_cars.groupby('Model')['Model'].size().nlargest(30)
# Out:
# Model
# SwiftDzire      189
# Grandi10        179
# WagonR          178
# Innova2.5       145
# Verna1.6        127
# City1.5         122
# Cityi           115
# Creta1.6        110
# NewC-Class      110
# 3Series         109
# SwiftVDI         96
# 5Series          86
# i201.2           78
# SantroXing       76
# XUV500W8         75
# i10Sportz        75
# AmazeS           69
# i10Magna         69
# Alto800          63
# CorollaAltis     63
# FigoDiesel       61
# Ecosport1.5      59
# A42.0            56
# AltoK10          56
# VitaraBrezza     55
# i20Asta          54
# InnovaCrysta     53
# i20Sportz        53
# Duster110PS      51
# Fortuner4x2      50
# Name: Model, dtype: int64

# %%
# we need to do statistical diagnostic Maybe in Tableau or SAS

# %%
used_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7252 entries, 0 to 7252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7252 non-null   object
#  1   Location           7252 non-null   object
#  2   Year               7252 non-null   int64
#  3   Kilometers_Driven  7252 non-null   int64
#  4   Fuel_Type          7252 non-null   object
#  5   Transmission       7252 non-null   object
#  6   Owner_Type         7252 non-null   object
#  7   Mileage            7250 non-null   float64
#  8   Engine             7206 non-null   float64
#  9   Power              7077 non-null   float64
#  10  Seats              7198 non-null   float64
#  11  New_Price          1006 non-null   float64
#  12  Price              6019 non-null   float64
#  13  age                7252 non-null   int64
#  14  Make               7252 non-null   object
#  15  Model              7252 non-null   object
# ...

# %%
used_cars.isnull().sum().sort_values(ascending=False)
# Out:
# New_Price            6246
# Price                1233
# Power                 175
# Seats                  54
# Engine                 46
# Mileage                 2
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# age                     0
# Make                    0
# Model                   0
# dtype: int64

# %%
#count missing value per row
num_missing=used_cars.isnull().sum(axis=1)
num_missing.value_counts()
# Out:
# 1    5232
# 2    1123
# 0     823
# 4      36
# 3      28
# 5      10
# dtype: int64

# %%
#Investigating how many missing values per row are there for each variable
for n in num_missing.value_counts().sort_index().index:
    if n > 0:
        print("*" *30,f'\nFor the rows with exactly {n} missing values, NAs are found in:')
        n_miss_per_col = used_cars[num_missing == n].isnull().sum()
        print(n_miss_per_col[n_miss_per_col > 0])
        print('\n\n')
# Out:
# ******************************
# For the rows with exactly 1 missing values, NAs are found in:
# Mileage         1
# New_Price    5049
# Price         182
# dtype: int64
#
#
#
# ******************************
# For the rows with exactly 2 missing values, NAs are found in:
# Mileage         1
# Power         102
# Seats           2
# New_Price    1123
# Price        1018
# dtype: int64
#
#
#
# ******************************
# For the rows with exactly 3 missing values, NAs are found in:
# Power        27
# Seats         6
# New_Price    28
# Price        23
# dtype: int64
#
#
#
# ******************************
# For the rows with exactly 4 missing values, NAs are found in:
# Engine       36
# Power        36
# Seats        36
# New_Price    36
# dtype: int64
#
#
#
# ******************************
# For the rows with exactly 5 missing values, NAs are found in:
# Engine       10
# Power        10
# Seats        10
# New_Price    10
# Price        10
# dtype: int64

# %%
used_cars[num_missing==5]
# Out:
#                                         Name   Location  Year  \
# S.No.
# 6042            Skoda Laura 1.8 TSI Ambition  Bangalore  2009
# 6541   Toyota Etios Liva Diesel TRD Sportivo  Bangalore  2012
# 6544           Hyundai i20 new Sportz AT 1.4  Bangalore  2012
# 6633                     Mahindra TUV 300 P4    Kolkata  2016
# 6643                 BMW 5 Series 520d Sedan  Bangalore  2009
# 6651                    Maruti Swift 1.3 VXi    Kolkata  2015
# 6677                  Fiat Punto 1.4 Emotion     Jaipur  2010
# 6685                    Maruti Swift 1.3 VXi       Pune  2010
# 6880                 BMW 5 Series 520d Sedan    Chennai  2009
# 6902                     Toyota Etios Liva V      Kochi  2012
#
#        Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# S.No.
# 6042               72000    Petrol       Manual     Second    17.50     NaN
# 6541               56600    Diesel       Manual      First    23.59     NaN
# ...

# %%
col=['Engine','Power']
used_cars[col].isnull().sum()
# Out:
# Engine     46
# Power     175
# dtype: int64

# %%
#filling missing values by grouping name and year and fill in missing values. with median.
used_cars.groupby(['Name','Year'])['Engine'].median().head(10)
# Out:
# Name                                 Year
# Ambassador Classic Nova Diesel       2003    1489.0
# Audi A3 35 TDI Attraction            2014    1968.0
# Audi A3 35 TDI Premium               2016    1968.0
# Audi A3 35 TDI Premium Plus          2015    1968.0
#                                      2016    1968.0
# Audi A3 35 TDI Technology            2017    1968.0
# Audi A4 1.8 TFSI                     2010    1781.0
#                                      2011    1781.0
# Audi A4 1.8 TFSI Technology Edition  2012    1798.0
# Audi A4 2.0 TDI                      2009    1968.0
# Name: Engine, dtype: float64

# %%
# will neeed to explain this
used_cars['Engine']=used_cars.groupby(['Name','Year'])['Engine'].apply(lambda x:x.fillna(x.median()))
used_cars['Power']=used_cars.groupby(['Name','Year'])['Power'].apply(lambda x:x.fillna(x.median()))

# %%
col=['Engine','Power']
used_cars[col].isnull().sum()
# Out:
# Engine     45
# Power     162
# dtype: int64

# %%
used_cars.groupby(['Make','Model'])['Engine'].median().head(3)
# Out:
# Make        Model
# Ambassador  ClassicNova    1489.0
# Audi        A335           1968.0
#             A41.8          1781.0
# Name: Engine, dtype: float64

# %%
#chosing Median to fill the the missing value as there are many outliers, 
#grouping by model and year to get  more granularity and more accurate Engine and then fillig with median
used_cars['Engine']=used_cars.groupby(['Make','Model'])['Engine'].apply(lambda x:x.fillna(x.median()))

# %%
#chosing Median to fill the the missing value as there are many outliers, 
#grouping by model to get more granularity and more accurate Engine
used_cars['Power']=used_cars.groupby(['Make','Model'])['Power'].apply(lambda x:x.fillna(x.median()))

# %%
col=['Engine','Power']
used_cars[col].isnull().sum()
# Out:
# Engine    18
# Power     63
# dtype: int64

# %%
used_cars.groupby(['Model','Year'])['Engine'].agg({'median','mean','max'}).sort_values(by='Model',ascending='True').head(10)
# Out:
#                      mean  median     max
# Model   Year
# 1000AC  1998   970.000000   970.0   970.0
# 1Series 2013  1995.000000  1995.0  1995.0
#         2015  1995.000000  1995.0  1995.0
# 370ZAT  2012  3696.000000  3696.0  3696.0
# 3Series 2018  1995.000000  1995.0  1995.0
#         2017  1995.000000  1995.0  1995.0
#         2016  1995.000000  1995.0  1995.0
#         2015  1995.000000  1995.0  1995.0
#         2014  2078.166667  1995.0  2993.0
#         2013  2066.428571  1995.0  2993.0

# %%
used_cars.groupby(['Make','Engine'])['Power'].agg({'mean','median','max'}).head(10)
# Out:
#                          mean  median     max
# Make       Engine
# Ambassador 1489.0   35.500000   35.50   35.50
# Audi       1395.0  147.510000  147.51  147.51
#            1781.0  163.200000  163.20  163.20
#            1798.0  181.033333  187.74  187.74
#            1968.0  167.123179  174.33  187.74
#            1984.0  196.022000  207.90  226.60
#            2698.0  179.500000  179.50  179.50
#            2773.0  201.000000  201.00  201.00
#            2894.0  444.000000  444.00  444.00
#            2967.0  241.740000  241.40  246.70

# %%
used_cars['Seats'].isnull().sum()
# Out:
# 54

# %%
used_cars['Seats']=used_cars.groupby(['Model'])['Seats'].apply(lambda x:x.fillna(x.median()))

# %%
used_cars['Seats'].isnull().sum()
# Out:
# 23

# %%
used_cars[used_cars['Seats'].isnull()==True].head(3)
# Out:
#                               Name   Location  Year  Kilometers_Driven  \
# S.No.
# 208           Maruti Swift 1.3 VXi    Kolkata  2010              42001
# 733           Maruti Swift 1.3 VXi    Chennai  2006              97800
# 1327          Maruti Swift 1.3 ZXI  Hyderabad  2015              50295
# 2074          Maruti Swift 1.3 LXI       Pune  2011              24255
# 2325      Maruti Swift 1.3 VXI ABS       Pune  2015              67000
# 2335          Maruti Swift 1.3 VXi     Mumbai  2007              55000
# 2369             Maruti Estilo LXI    Chennai  2008              56000
# 2668          Maruti Swift 1.3 VXi    Kolkata  2014              32986
# 3404          Maruti Swift 1.3 VXi     Jaipur  2006             125000
# 3810   Honda CR-V AT With Sun Roof    Kolkata  2013              27000
#
#       Fuel_Type Transmission      Owner_Type  Mileage  Engine  Power  Seats  \
# S.No.
# 208      Petrol       Manual           First     16.1     NaN    NaN    NaN
# ...

# %%
dictionary= pd.read_csv(r'C:\Users\s_kel\OneDrive\Documents\Programming for Analytics\project\Dictionary.csv')
dictionary
# Out:
#     S/N          Variables                          Description of Variables
# 0     1               Name                                        Car details
# 1     2           Location                        Where the car is being sold
# 2     3               Year     Number of years since the car was manufactured
# 3     4  Kilometers_Driven                   Distance driven by the car in km
# 4     5          Fuel_Type                  indicate the fuel type of the car
# 5     6       Transmission               indicate the Transmission of the car
# 6     7         Owner_Type  car has been sold earlier (current owner is th...
# 7     8            Mileage                                      Car's mileage
# 8     9             Engine                                   Engine capacity
# 9    10              Power                                    Power capacity
# 10   11              Seats                            No. of seats in the car
# ...

# %%
used_cars['Seats'].value_counts()
# Out:
# 5.0     6075
# 7.0      798
# 8.0      170
# 4.0      119
# 6.0       38
# 2.0       18
# 10.0       8
# 9.0        3
# Name: Seats, dtype: int64

# %%
#most of cars are 5 seater so fillrest of 23 by 5
used_cars['Seats']=used_cars['Seats'].fillna(5)

# %%
used_cars['Seats'].isnull().sum()
# Out:
# 0

# %%
used_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7252 entries, 0 to 7252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7252 non-null   object
#  1   Location           7252 non-null   object
#  2   Year               7252 non-null   int64
#  3   Kilometers_Driven  7252 non-null   int64
#  4   Fuel_Type          7252 non-null   object
#  5   Transmission       7252 non-null   object
#  6   Owner_Type         7252 non-null   object
#  7   Mileage            7250 non-null   float64
#  8   Engine             7234 non-null   float64
#  9   Power              7189 non-null   float64
#  10  Seats              7252 non-null   float64
#  11  New_Price          1006 non-null   float64
#  12  Price              6019 non-null   float64
#  13  age                7252 non-null   int64
#  14  Make               7252 non-null   object
#  15  Model              7252 non-null   object
# ...

# %%
used_cars['New_Price']=used_cars.groupby(['Name','Year'])['New_Price'].apply(lambda x:x.fillna(x.median()))

# %%
used_cars.New_Price.isnull().sum()
# Out:
# 6138

# %%
used_cars['New_Price']=used_cars.groupby(['Make','Model'])['New_Price'].apply(lambda x:x.fillna(x.median()))

# %%
used_cars.New_Price.isnull().sum()
# Out:
# 4578

# %%
used_cars['New_Price']=used_cars.groupby(['Make'])['New_Price'].apply(lambda x:x.fillna(x.median()))

# %%
used_cars.New_Price.isnull().sum()
# Out:
# 158

# %%
cols1 = ["Power","Mileage","Engine"]

for ii in cols1:
    used_cars[ii] = used_cars[ii].fillna(used_cars[ii].median())

# %%
#dropping remaining rows
#cannot further fill this rows so dropping them

used_cars.dropna(inplace=True,axis=0)

# %%
used_cars.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# New_Price            0
# Price                0
# age                  0
# Make                 0
# Model                0
# dtype: int64

# %%
used_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5892 entries, 0 to 6017
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5892 non-null   object
#  1   Location           5892 non-null   object
#  2   Year               5892 non-null   int64
#  3   Kilometers_Driven  5892 non-null   int64
#  4   Fuel_Type          5892 non-null   object
#  5   Transmission       5892 non-null   object
#  6   Owner_Type         5892 non-null   object
#  7   Mileage            5892 non-null   float64
#  8   Engine             5892 non-null   float64
#  9   Power              5892 non-null   float64
#  10  Seats              5892 non-null   float64
#  11  New_Price          5892 non-null   float64
#  12  Price              5892 non-null   float64
#  13  age                5892 non-null   int64
#  14  Make               5892 non-null   object
#  15  Model              5892 non-null   object
# ...

# %%
used_cars.groupby(['Make'])['Price'].agg({'median','mean','max'})
# Out:
#                     mean  median     max
# Make
# Audi           25.537712  23.500   72.94
# BMW            25.243146  21.000   93.67
# Bentley        59.000000  59.000   59.00
# Datsun          3.049231   3.100    3.95
# Fiat            3.269286   2.600    7.71
# Ford            6.889400   5.345   56.80
# Honda           5.411743   4.950   17.50
# Hyundai         5.343433   4.600   23.00
# Isuzu          14.696667  16.090   20.00
# Jaguar         37.632250  31.900  100.00
# Jeep           18.718667  18.500   23.91
# Land Rover     39.259500  35.000  160.00
# Mahindra        8.045919   7.570   17.63
# Maruti          4.517267   4.150   11.50
# Mercedes-Benz  26.809874  24.000   90.00
# Mini Cooper    26.896923  24.285   39.75
# Mitsubishi     11.058889   9.950   28.00
# Nissan          4.738352   4.300    8.92
# Porsche        48.348333  47.020   75.00
# Renault         5.799034   5.490   14.01
# Skoda           7.559075   6.000   27.30
# Tata            3.562849   2.900   17.85
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
sns.heatmap(used_cars.corr(),annot=True ,cmap="YlGnBu" )
plt.show()

# %%
sns.pairplot(data=used_cars , corner=True)
plt.show()

# %%
# Impact of years on price 
plt.figure(figsize=(10,7))
plt.title("Price based on manufacturing Year of model")
sns.lineplot(x='Year', y='Price',hue='Transmission',
             data=used_cars)
# Out:
# <AxesSubplot:title={'center':'Price based on manufacturing Year of model'}, xlabel='Year', ylabel='Price'>

# %%
# Impact of years on price 
plt.figure(figsize=(10,7))
plt.title("Price Vs Year VS FuelType")
sns.lineplot(x='Year', y='Price',hue='Fuel_Type',
             data=used_cars)
# Out:
# <AxesSubplot:title={'center':'Price Vs Year VS FuelType'}, xlabel='Year', ylabel='Price'>

# %%
# Understand relationships  between price and mileage
plt.figure(figsize=(10,7))
plt.title("Price Vs Mileage")
sns.scatterplot(y='Price', x='Mileage', hue='Fuel_Type', data=used_cars)
# Out:
# <AxesSubplot:title={'center':'Price Vs Mileage'}, xlabel='Mileage', ylabel='Price'>

# %%
#Price and seats 
plt.figure(figsize=(20,15))
sns.set(font_scale=2)
sns.barplot(x='Seats', y='Price', data=used_cars)
plt.grid()

# %%
#Price and Location 
plt.figure(figsize=(20,15))
sns.set(font_scale=2)
sns.barplot(x='Location', y='Price', data=used_cars)
plt.grid()

# %%
sns.relplot(data=used_cars, y='Price',x='Mileage',hue='Transmission',aspect=1,height=5)

# %%
used_cars.to_excel('used_cars.xlsx')
